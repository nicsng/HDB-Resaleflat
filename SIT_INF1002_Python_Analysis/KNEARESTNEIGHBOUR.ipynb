# %%
# Load libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data set
df = pd.read_excel("C://Users//Denzel//Desktop//resaleflatprice_140922.xlsx", sheet_name="resale-flat-prices-based-on-reg")

# %%
df.head()
# Out:
#        month        town flat_type block        street_name storey_range  \
# 0 2015-01-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1 2015-01-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2 2015-01-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3 2015-01-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4 2015-01-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0              60        Improved                 1986               70
# 1              68  New Generation                 1981               65
# 2              69  New Generation                 1980               64
# 3              68  New Generation                 1979               63
# 4              68  New Generation                 1980               64
#
#    resale_price
# 0        255000
# 1        275000
# 2        285000
# 3        290000
# ...

# %%
#Histogram, number of data entries of each town
sns.set()
plt.xticks(rotation=90) #for very long labels
sns.countplot(x="town", data=df, palette="ch:.25")
# Out:
# <AxesSubplot:xlabel='town', ylabel='count'>

# %%
average_price=df.groupby('town')['resale_price'].mean()
average_price=round(average_price)
average_price.plot(kind='barh', color='purple', title="Average Price of a flat per town")
# Out:
# <AxesSubplot:title={'center':'Average Price of a flat per town'}, ylabel='town'>

# %%
average_price=df.groupby('flat_type')['resale_price'].mean()
average_price=round(average_price)
average_price.plot(kind='bar', color='violet', title="Average Price of a flat per type")
# Out:
# <AxesSubplot:title={'center':'Average Price of a flat per type'}, xlabel='flat_type'>

# %%
##### plotly go objeccts try test #####


from flask import Flask, render_template
import pandas as pd
import json
import plotly
import plotly.figure_factory as ff
import plotly.express as px
import numpy as np

# Standard plotly imports
from chart_studio import plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
# Using plotly + cufflinks in offline mode
import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
##### plotly go objeccts try test #####

df5 = pd.read_excel("C://Users//Denzel//Desktop//resaleflatprice_140922.xlsx", sheet_name="resale-flat-prices-based-on-reg")

average_price_town=df5.groupby('town', as_index=False)['resale_price'].mean()
average_price_type=df5.groupby('flat_type', as_index=False)['resale_price'].mean()

df55 = pd.DataFrame(average_price_town)
df66 = pd.DataFrame(average_price_type)
#fig5 = px.bar(df55, y='resale_price')

s_town = df55['town'].to_numpy()
s_price = df55['resale_price'].to_numpy()

s_type = df66['flat_type'].to_numpy()
s_price2 = df66['resale_price'].to_numpy()


#for col in df55.columns:
#    print(col)

plot = go.Figure(data=[go.Bar(
    name='Town',
    x=s_town,
    y=s_price
),
    go.Bar(
    name='flat Type',
    x=s_type,
    y=s_price2, visible=False
)])


# Add dropdown
plot.update_layout(
    updatemenus=[
        dict(
            active=0,
            buttons=list([
                dict(label="Town",
                     method="update",
                     args=[{"visible": [True, False]},
                           {"title": "Town",
                            }]),
                dict(label="Flat Type",
                     method="update",
                     args=[{"visible": [False, True]},
                           {"title": "Flat Type",
                            }]),
            ]),
        )
    ])

plot
# Out:
# <div>                            <div id="7610540b-aa7d-4ac3-8691-17b67881fdee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7610540b-aa7d-4ac3-8691-17b67881fdee")) {                    Plotly.newPlot(                        "7610540b-aa7d-4ac3-8691-17b67881fdee",                        [{"name":"Town","x":["ANG MO KIO","BEDOK","BISHAN","BUKIT BATOK","BUKIT MERAH","BUKIT PANJANG","BUKIT TIMAH","CENTRAL AREA","CHOA CHU KANG","CLEMENTI","GEYLANG","HOUGANG","JURONG EAST","JURONG WEST","KALLANG/WHAMPOA","MARINE PARADE","PASIR RIS","PUNGGOL","QUEENSTOWN","SEMBAWANG","SENGKANG","SERANGOON","TAMPINES","TOA PAYOH","WOODLANDS","YISHUN"],"y":[408422.98217179906,406363.50573300576,602681.998540146,391228.3530979347,540764.5655677656,410759.2789699571,709368
# ...

# %%
df.head()
# Out:
#        month        town flat_type block        street_name storey_range  \
# 0 2015-01-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1 2015-01-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2 2015-01-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3 2015-01-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4 2015-01-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0              60        Improved                 1986               70
# 1              68  New Generation                 1981               65
# 2              69  New Generation                 1980               64
# 3              68  New Generation                 1979               63
# 4              68  New Generation                 1980               64
#
#    resale_price
# 0        255000
# 1        275000
# 2        285000
# 3        290000
# ...

# %%
################plotly custom graph try try laaaalalalalalallaa #################

##### plotly go objeccts try test #####

df5 = pd.read_excel("C://Users//Denzel//Desktop//resaleflatprice_140922.xlsx", sheet_name="resale-flat-prices-based-on-reg")

average_price_town=df5.groupby('town', as_index=False)['resale_price'].median()
average_price_type=df5.groupby('flat_type', as_index=False)['resale_price'].median()
average_price_month=df5.groupby('month', as_index=False)['resale_price'].median()
average_price_storey=df5.groupby('storey_range', as_index=False)['resale_price'].median()
average_price_areasq=df5.groupby('floor_area_sqm', as_index=False)['resale_price'].median()
average_price_model=df5.groupby('flat_model', as_index=False)['resale_price'].median()
average_price_lease=df5.groupby('remaining_lease', as_index=False)['resale_price'].median()


df55 = pd.DataFrame(average_price_town)
df66 = pd.DataFrame(average_price_type)
df77 = pd.DataFrame(average_price_month)
df88 = pd.DataFrame(average_price_storey)
df99 = pd.DataFrame(average_price_areasq)
df100 = pd.DataFrame(average_price_model)
df101 = pd.DataFrame(average_price_lease)


s_town = df55['town'].to_numpy()
s_price = df55['resale_price'].to_numpy()

s_type = df66['flat_type'].to_numpy()
s_price2 = df66['resale_price'].to_numpy()

s_month = df77['month'].to_numpy()
s_price3 = df77['resale_price'].to_numpy()

s_storey = df88['storey_range'].to_numpy()
s_price4 = df88['resale_price'].to_numpy()

s_areasq = df99['floor_area_sqm'].to_numpy()
s_price5 = df99['resale_price'].to_numpy()

s_model = df100['flat_model'].to_numpy()
s_price6 = df100['resale_price'].to_numpy()

s_lease = df101['remaining_lease'].to_numpy()
s_price7 = df101['resale_price'].to_numpy()


plot = go.Figure(data=[go.Bar(
    name='Town',
    x=s_town,
    y=s_price
),
    go.Bar(
    name='month',
    x=s_month,
    y=s_price3, visible=False
),
    go.Bar(
    name='storey_range',
    x=s_storey,
    y=s_price4, visible=False
),
    go.Bar(
    name='flat Type',
    x=s_type,
    y=s_price2, visible=False
),
    go.Bar(
    name='floor area sqm',
    x=s_areasq,
    y=s_price5, visible=False
),
    go.Bar(
    name='Flat Model',
    x=s_model,
    y=s_price6, visible=False
),
    go.Bar(
    name='Remaining Lease',
    x=s_lease,
    y=s_price7, visible=False
)
                      
                      
                      
                      
                      ])


# Add dropdown
plot.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                dict(
                    args=["type", "bar"],
                    label="Bar Chart",
                    method="restyle"
                ),
                dict(
                    args=[{"mode": "markers", "type": "scatter"}],
                    label="Scatter Plot",
                    method="restyle"
                ),
                dict(
                    args=[{"mode": "lines", "type": "pie", "textinfo":"label+percent", "textposition":"inside"}],
                    label="Pie Chart",
                    method="restyle"
                ),
                dict(
                    args=[{"mode": "lines", "type": "scatter"}],
                    label="Line Chart",
                    method="restyle"
                )
            ]),
            direction="down",
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0.1,
            xanchor="left",
            y=1.5,
            yanchor="top"
        ),
        
        
        dict(
            active=0,
            buttons=list([
                dict(label="Town",
                     method="update",
                     args=[{"visible": [True, False, False, False, False, False, False]},
                           {"title": "Flat Type",
                            }]),
                dict(label="Month",
                     method="update",
                     args=[{"visible": [False, True, False, False, False, False, False]},
                           {"title": "Month",
                            }]),
                dict(label="Storey",
                     method="update",
                     args=[{"visible": [False, False, True, False, False, False, False]},
                           {"title": "Storey",
                            }]),
                dict(label="Flat Type",
                     method="update",
                     args=[{"visible": [False, False, False, True, False, False, False]},
                           {"title": "Flat Type",
                            }]),
                dict(label="Floor area sqm",
                     method="update",
                     args=[{"visible": [False, False, False, False, True, False, False]},
                           {"title": "Flat Type",
                            }]),
                dict(label="Flat Model",
                     method="update",
                     args=[{"visible": [False, False, False, False, False, True, False]},
                           {"title": "Flat Model",
                            }]),
                dict(label="Remaining Lease",
                     method="update",
                     args=[{"visible": [False, False, False, False, False, False, True]},
                           {"title": "Remaining Lease",
                            }]),
                
                
                
            ]),
            direction="down",
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0.3,
            xanchor="left",
            y=1.5,
            yanchor="top"
        )
        
        
    ]
)

plot
# Out:
# <div>                            <div id="1b542754-7c00-4631-95d8-81f3fc9b7af2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b542754-7c00-4631-95d8-81f3fc9b7af2")) {                    Plotly.newPlot(                        "1b542754-7c00-4631-95d8-81f3fc9b7af2",                        [{"name":"Town","x":["ANG MO KIO","BEDOK","BISHAN","BUKIT BATOK","BUKIT MERAH","BUKIT PANJANG","BUKIT TIMAH","CENTRAL AREA","CHOA CHU KANG","CLEMENTI","GEYLANG","HOUGANG","JURONG EAST","JURONG WEST","KALLANG/WHAMPOA","MARINE PARADE","PASIR RIS","PUNGGOL","QUEENSTOWN","SEMBAWANG","SENGKANG","SERANGOON","TAMPINES","TOA PAYOH","WOODLANDS","YISHUN"],"y":[355000.0,373000.0,588000.0,363800.0,539000.0,385000.0,710000.0,665944.0,377000.0,385000.0,372000.0,390000.0,390000.
# ...

# %%
### go object pie chart
df123 = pd.read_excel("C://Users//Denzel//Desktop//resaleflatprice_140922.xlsx", sheet_name="resale-flat-prices-based-on-reg")


#Get storey range as a continuous number
#df123['storey_range'] = df123['storey_range'].apply(lambda storey_range:storey_range[:2]) 
flattype_count = df123['storey_range'].value_counts()
count_results = pd.DataFrame(flattype_count)
count_results = count_results.reset_index()  
count_results.columns = ['storey_ranges', 'resale_sold']

flattype2_count = df123['flat_type'].value_counts()
count_results2 = pd.DataFrame(flattype2_count)
count_results2 = count_results2.reset_index()  
count_results2.columns = ['flat_type', 'resale_sold']

labels = count_results['storey_ranges']
labels2= count_results2['flat_type']
values = count_results['resale_sold']
values2 = count_results2['resale_sold']


fig = go.Figure(data=[go.Pie(labels=labels, values=values, name='Flat type', textinfo='label+percent', textposition='inside'),
                      go.Pie(labels=labels2, values=values, name='Storey range', textinfo='label+percent',visible= False, textposition='inside')])


# Add dropdown
fig.update_layout(
    updatemenus=[
        dict(
            active=0,
            buttons=list([
                dict(label="Flat type",
                     method="update",
                     args=[{"visible": [True, False]},
                           {"title": "Flat type",
                            }]),
                dict(label="Storey range",
                     method="update",
                     args=[{"visible": [False, True]},
                           {"title": "Storey range",
                            }]),
            ]),
        )
    ])


fig
# Out:
# <div>                            <div id="77ceacce-ad7b-4620-9c21-fa08c6717c3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77ceacce-ad7b-4620-9c21-fa08c6717c3c")) {                    Plotly.newPlot(                        "77ceacce-ad7b-4620-9c21-fa08c6717c3c",                        [{"labels":["04 TO 06","07 TO 09","01 TO 03","10 TO 12","13 TO 15","16 TO 18","19 TO 21","22 TO 24","25 TO 27","28 TO 30","34 TO 36","37 TO 39","31 TO 33","40 TO 42","46 TO 48","43 TO 45","49 TO 51"],"name":"Flat type","textinfo":"label+percent","textposition":"inside","values":[8961,8220,7050,7048,3176,1300,514,369,189,119,55,54,53,27,8,8,2],"type":"pie"},{"labels":["4 ROOM","3 ROOM","5 ROOM","EXECUTIVE","2 ROOM","1 ROOM","MULTI-GENERATION"],"name":"Storey range"
# ...

# %%
dataframe = pd.read_excel("C://Users//Denzel//Desktop//resaleflatprice_140922.xlsx")

year_count = dataframe['month'].value_counts()

count_results = pd.DataFrame(year_count)

count_results = count_results.reset_index()  

count_results.columns = ['month_and_year', 'resale_sold']

fig = px.bar(count_results, x='month_and_year', y='resale_sold', title='hdb units sold per month in years', color='resale_sold')
fig
# Out:
# <div>                            <div id="e193cecb-63c3-4579-bc8a-27301cd0d1bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e193cecb-63c3-4579-bc8a-27301cd0d1bc")) {                    Plotly.newPlot(                        "e193cecb-63c3-4579-bc8a-27301cd0d1bc",                        [{"alignmentgroup":"True","hovertemplate":"month_and_year=%{x}<br>resale_sold=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[6439,5834,5690,5681,5655,5479,5197,4978,4976,4823,4784,4753,4434,4386,4044,3895,3783,3773,3718,3690,3673,3512,3488,3482,3482,3428,3387,3368,3344,3339,3325,3316,3294,3294,3293,3288,3276,3276,3261,3236,3229,3224,3210,3209,3160,3160,3151,3144,3108,3098,3088,3086,3082,3075,3067,3035,3034,3020,2998,2995,2983,2973,2956,2925,29
# ...

# %%
# df4 = pd.read_excel("C://Users//Denzel//Desktop//resaleflatprice_140922.xlsx", sheet_name="resale-flat-prices-based-on-reg")
# #fig4 = px.scatter(df4, x="floor_area_sqm", y="resale_price", color_discrete_sequence=['pink'], trendline="ols",trendline_color_override="red")

# s_x = df4['floor_area_sqm'].to_numpy()
# s_x2 = df4['remaining_lease'].to_numpy()
# s_price = df4['resale_price'].to_numpy()

# plot = go.Figure(data=[go.Scatter(
#     name='Data 1',
#     x=s_x,
#     y=s_price,
#     mode='markers',),
                       
#     go.Scatter(
#     name='Data 2',
#     x=s_x2,
#     y=s_price,
#     mode='markers',visible=False)
# ])


# plot.update_layout(
#     updatemenus=[
#         dict(
#             active=0,
#             buttons=list([
#                 dict(label="Data 1",
#                      method="update",
#                      args=[{"visible": [True, False]},
#                            {"title": "Data 1",
#                             }]),
#                 dict(label="Data 2",
#                      method="update",
#                      args=[{"visible": [False, True]},
#                            {"title": "Data 2",
#                             }]),
#             ]),
#         )
#     ])

#plot
#remaining_lease

# %%
average_price=df.groupby('lease_commence_date')['resale_price'].mean()
average_price=round(average_price)
plt.plot(average_price, color='olive')
plt.show()

# %%
df11 = pd.read_excel("C://Users//Denzel//Desktop//resaleflatprice_140922.xlsx", sheet_name="resale-flat-prices-based-on-reg")

average_price_lease=df11.groupby('lease_commence_date', as_index=False)['resale_price'].mean()
df111 = pd.DataFrame(average_price_lease)

fig = px.line(df111, x="lease_commence_date", y="resale_price", title='Prices over time')
fig
# Out:
# <div>                            <div id="19bae9f7-9778-4a68-b867-a0b564903ef5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19bae9f7-9778-4a68-b867-a0b564903ef5")) {                    Plotly.newPlot(                        "19bae9f7-9778-4a68-b867-a0b564903ef5",                        [{"hovertemplate":"lease_commence_date=%{x}<br>resale_price=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,20
# ...

# %%
df11 = pd.read_excel("C://Users//Denzel//Desktop//resaleflatprice_140922.xlsx", sheet_name="resale-flat-prices-based-on-reg")

#group by averages etc
mean_price_lease=df11.groupby('lease_commence_date', as_index=False)['resale_price'].mean()
median_price_lease=df11.groupby('lease_commence_date', as_index=False)['resale_price'].median()
max_price_lease=df11.groupby('lease_commence_date', as_index=False)['resale_price'].max()
min_price_lease=df11.groupby('lease_commence_date', as_index=False)['resale_price'].min()

#convert groupby to dataframe
dfmean = pd.DataFrame(mean_price_lease)
dfmedian = pd.DataFrame(median_price_lease)
dfmax = pd.DataFrame(max_price_lease)
dfmin = pd.DataFrame(min_price_lease)

#convert dataframe to numpy array
s_mean = dfmean['resale_price'].to_numpy()
s_median = dfmedian['resale_price'].to_numpy()
s_max = dfmax['resale_price'].to_numpy()
s_min = dfmin['resale_price'].to_numpy()
s_year = dfmin['lease_commence_date'].to_numpy()

# Create graph
fig = go.Figure()

fig.add_trace(go.Scatter(x=s_year, y=s_mean,
                    mode='lines',
                    name='Mean Price'))
fig.add_trace(go.Scatter(x=s_year, y=s_median,
                    mode='lines',
                    name='Median Price'))
fig.add_trace(go.Scatter(x=s_year, y=s_max,
                    mode='lines',
                    name='Max Price'))
fig.add_trace(go.Scatter(x=s_year, y=s_min,
                    mode='lines',
                    name='Min Price'))

# #creating count
# fcount = df11['lease_commence_date'].value_counts()
# dfcount = pd.DataFrame(fcount)
# dfcount.reset_index(inplace=True)
# dfcount.columns = ['lease_commence_date', 'count']
# dfcount = dfcount.sort_values('lease_commence_date')
# s_count = dfcount['count'].to_numpy()

# #adding count bar chart
# fig.add_trace(go.Bar(x=s_year, y=s_count, visible = True))


# Add dropdown
fig.update_layout(
    updatemenus=[
        dict(
            active=0,
            buttons=list([
                dict(label="All",
                     method="update",
                     args=[{"visible": [True]},
                           {"title": "Resale Price over time",
                            }]),
                dict(label="Mean Price",
                     method="update",
                     args=[{"visible": [True, False, False, False]},
                           {"title": "Mean Price",
                            }]),
                dict(label="Median Price",
                     method="update",
                     args=[{"visible": [False, True, False, False]},
                           {"title": "Median Price",
                            }]),
                dict(label="Max Price",
                     method="update",
                     args=[{"visible": [False,False, True, False]},
                           {"title": "Max Price",
                            }]),
                dict(label="Min Price",
                     method="update",
                     args=[{"visible": [False, False, False,True]},
                           {"title": "Min Price",
                            }]),
                
            ]),
        )
    ])

fig
# Out:
# <div>                            <div id="88740aa3-8bf1-4a6c-a7fe-1e1aa0ab8499" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88740aa3-8bf1-4a6c-a7fe-1e1aa0ab8499")) {                    Plotly.newPlot(                        "88740aa3-8bf1-4a6c-a7fe-1e1aa0ab8499",                        [{"mode":"lines","name":"Mean Price","x":[1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013],"y":[266333.3333333333,290270.8376068376,340004.38095238095,301023.8608695652,323741.07692307694,285613.109947644,365587.0725388601,365516.703862661,385592.28571428574,427300.0236686390
# ...

# %%
sns.set()
#plt.xticks(y_pos, names, rotation=90) #for very long labels
plt.xticks(rotation=90) #for very long labels
sns.countplot(x="flat_type", data=df, palette="hls")
# Out:
# <AxesSubplot:xlabel='flat_type', ylabel='count'>

# %%
# Standard plotly imports
from chart_studio import plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
# Using plotly + cufflinks in offline mode
import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
df['storey_range'].iplot(kind='hist', xTitle='race', yTitle='count', color="blue")
#can be viewed using jupiter notebook
#interactive country distribution
# Out:
# <div>                            <div id="c97eaa50-e7be-4fa7-b3ec-f1deb0278881" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import math
import tensorflow as tf
from collections import defaultdict
import numpy as np
from numpy import unique
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, TensorBoard

# %%
#create dataframe for ML as copy of df
dataframe = df.copy()

# %%
dataframe.head()
# Out:
#    town  flat_type storey_range  floor_area_sqm  remaining_lease  resale_price
# 0     1          3           07              60               70        255000
# 1     1          3           01              68               65        275000
# 2     1          3           01              69               64        285000
# 3     1          3           01              68               63        290000
# 4     1          3           07              68               64        290000

# %%
# drop some unnecessary columns for ML
dataframe = dataframe.drop('block',axis=1)
dataframe = dataframe.drop('month',axis=1)
dataframe = dataframe.drop('street_name',axis=1)
dataframe = dataframe.drop('flat_model',axis=1)
dataframe = dataframe.drop('lease_commence_date',axis=1)

# %%
#Encoding Qualitative data
townDict = {'ANG MO KIO': 1,'BEDOK': 2,'BISHAN': 3,'BUKIT BATOK': 4,'BUKIT MERAH': 5,'BUKIT PANJANG': 6,'BUKIT TIMAH': 7,'CENTRAL AREA': 8,'CHOA CHU KANG': 9,'CLEMENTI': 10,'GEYLANG': 11,'HOUGANG': 12,'JURONG EAST': 13,'JURONG WEST': 14,'KALLANG/WHAMPOA': 15,'MARINE PARADE': 16,'PASIR RIS': 17,'PUNGGOL': 18,'QUEENSTOWN': 19,'SEMBAWANG': 20,'SENGKANG': 21,'SERANGOON': 22,'TAMPINES': 23,'TOA PAYOH': 24,'WOODLANDS': 25,'YISHUN': 26,}
flat_typeDict = {'1 ROOM': 1,'2 ROOM': 2,'3 ROOM': 3,'4 ROOM': 4,'5 ROOM': 5,'EXECUTIVE': 6,'MULTI-GENERATION': 7,}

dataframe['town'] = dataframe['town'].replace(townDict, regex=True)
dataframe['flat_type'] = dataframe['flat_type'].replace(flat_typeDict, regex=True)

# %%
#Get storey range as a continuous number
dataframe['storey_range'] = dataframe['storey_range'].apply(lambda storey_range:storey_range[:2])

# %%
dataframe
# Out:
#        town  flat_type storey_range  floor_area_sqm  remaining_lease  \
# 0         1          3           07              60               70
# 1         1          3           01              68               65
# 2         1          3           01              69               64
# 3         1          3           01              68               63
# 4         1          3           07              68               64
# ...     ...        ...          ...             ...              ...
# 37148    26          5           13             112               82
# 37149    26          5           01             122               69
# 37150    26          6           10             181               74
# 37151    26          6           01             146               70
# 37152    26          7           10             164               70
#
#        resale_price
# 0            255000
# 1            275000
# 2            285000
# 3            290000
# 4            290000
# ...

# %%
#Train and test splitting
X = dataframe.drop('resale_price',axis =1).values
y = dataframe['resale_price'].values

#splitting Train and Test 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
#Scaling the data
#standardization scaler - fit&transform on train, fit only on test

s_scaler = StandardScaler()
X_train = s_scaler.fit_transform(X_train.astype(np.float))
X_test = s_scaler.transform(X_test.astype(np.float))
# Out:
# C:\Users\Denzel\AppData\Local\Temp\ipykernel_20472\1878709497.py:5: DeprecationWarning:
#
# `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# C:\Users\Denzel\AppData\Local\Temp\ipykernel_20472\1878709497.py:6: DeprecationWarning:
#
# `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
#KNN Model
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(algorithm='brute')

# %%
knn.fit(X_train,y_train)
predictions = knn.predict(X_test)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, predictions)
rmse = mse ** (1/2)
print("RMSE =",rmse)
# Out:
# RMSE = 55884.18044002043

# %%
dfx = pd.DataFrame({'Actual': y_test, 'Predicted': predictions})
df1 = dfx.head(15)
df1
# Out:
#     Actual  Predicted
# 0   565000   614577.6
# 1   440488   432400.0
# 2   305000   334400.0
# 3   471000   487400.0
# 4   510000   483400.0
# 5   615000   541600.0
# 6   410000   395537.6
# 7   338000   356377.6
# 8   320000   323600.0
# 9   320000   326000.0
# 10  370000   363177.6
# 11  352000   394600.0
# 12  250000   268800.0
# 13  460000   528600.0
# 14  640000   567600.0

# %%
customDf = {'town': [1], 'flat_type': [3], 'storey_range':['07'], 'floor_area_sqm':[165], 'remaining_lease': [70]}
customDf = pd.DataFrame(customDf)
customDf = s_scaler.transform(customDf.astype(np.float))

output = str(knn.predict(customDf))
output = str(output).replace("[", "")
output = output.replace("]", "")
output = output.replace(".", "")
print("The Predicted Price is: "+"$"+output)
# Out:
# The Predicted Price is: $639600
# C:\Users\Denzel\AppData\Local\Temp\ipykernel_20472\2404823139.py:3: DeprecationWarning:
#
# `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# C:\Users\Denzel\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:443: UserWarning:
#
# X has feature names, but StandardScaler was fitted without feature names
